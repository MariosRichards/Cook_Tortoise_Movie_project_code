# %%
# basic python data handling analysis modules
import numpy as np, pandas as pd, matplotlib.pyplot as plt, seaborn as sns
sns.set()
import pickle, os, gc, re
# small utility functions
from utility import *

# interactive jupyter widgets!
# https://towardsdatascience.com/interactive-controls-for-jupyter-notebooks-f5c94829aee6
import ipywidgets as widgets
from ipywidgets import interact, interact_manual

# %matplotlib inline

# %%
Dataset_directory = ".."+os.sep+"Datasets"+os.sep

# %%
INT_df = pd.read_msgpack(Dataset_directory+"Processed"+os.sep+"INT_df_with_aggregate"+".msgpack")
tv_series_mislabelled_as_a_movie = INT_df[INT_df["TMB_tv_not_film"]==1].index
INT_df.drop(tv_series_mislabelled_as_a_movie,inplace=True)

# %%
INT_df_ord_only = pd.read_msgpack(Dataset_directory+"Processed"+os.sep+"INT_df_ord_only"+".msgpack")

# %%
# rename some variables???

INT_df_ord_only.rename(index=str, columns={"gender_guess_integrated_crew_lead5": "fraction_male_crew_lead5",
                                           "gender_guess_integrated_cast_lead10": "fraction_male_cast_lead10"},
                       inplace=True)

# %%
INT_df_ord_only.drop(["SER_release_year","SER_release_month","SER_release_day"],axis=1,inplace=True)

# %%
search(INT_df_ord_only,"year")
# Out:
# release_year    49513
# dtype: int64

# %%
# TMB_runtime, release_year
search(INT_df,"TMB_runtime")
# Out:
# TMB_runtime    43539
# dtype: int64

# %%
# sns.set()
plt.figure(figsize=(16,12));
sns.lineplot(x="release_year", y="TMB_runtime", data=INT_df, ci=68);

# %%
# sns.set()
plt.figure(figsize=(16,12));
sns.lineplot(x="release_year", y="TMB_runtime", data=INT_df[ (INT_df["release_year"]<=2010)
                                                            &(INT_df["release_year"]>=1920)], ci=68,err_style ='bars');

# %%
release_decade = INT_df["release_year"].apply(lambda x: str(int(10*np.floor(x/10))) if pd.notnull(x) else np.nan)

# %%
release_decade.value_counts()
# Out:
# 2010    14642
# 2000    11833
# 1990     5896
# 1980     4172
# 1970     3800
# 1960     3003
# 1950     2213
# 1940     1645
# 1930     1453
# 1920      452
# 1910      198
# 1900      110
# 1890       85
# 1880        6
# 2020        3
# 1870        2
# Name: release_year, dtype: int64

# %%
# Out:
# Index(['1890', '1900', '1910', '1920', '1930', '1940', '1950', '1960', '1970',
#        '1980', '1990', '2000', '2010'],
#       dtype='object')

# %%
release_decade.replace(["1880","1870","2020"], np.nan,inplace=True)

# %%
plt.figure(figsize=(16,8));
sns.lineplot(x=release_decade, y=INT_df["TMB_runtime"]);

# %%
plt.figure(figsize=(16,8));
sns.violinplot(x=release_decade, y=INT_df["TMB_runtime"],
               order = release_decade.value_counts().sort_index().index,
              palette='muted', scale='width', cut=0,bw=.01);
# probably not the bandwidth granularity to go with, but has a nice Rorschach feel to it "Which of these butterflies would you like to murder while pretending it's your mother?"

# %%
plt.figure(figsize=(16,8));
sns.boxplot(x=release_decade, y=INT_df["TMB_runtime"],
               order = release_decade.value_counts().sort_index().index,
              palette='muted',);

# %%
plt.figure(figsize=(16,8));
sns.boxenplot(x=release_decade, y=INT_df["TMB_runtime"],
               order = release_decade.value_counts().sort_index().index,
              palette='muted',);
# I think this wins on cuteness

# %%
# # unspeakably slow! c
# plt.figure(figsize=(16,8));
# sns.swarmplot(x=release_decade, y=INT_df["TMB_runtime"], order = release_decade.value_counts().sort_index().index);

# %%
plt.figure(figsize=(16,8));
sns.stripplot(x=release_decade, y=INT_df["TMB_runtime"], order = release_decade.value_counts().sort_index().index);

# %%
release_decade.value_counts().sort_index().index
# Out:
# Index(['1890', '1900', '1910', '1920', '1930', '1940', '1950', '1960', '1970',
#        '1980', '1990', '2000', '2010'],
#       dtype='object')

# %%
# Out:
# Int64Index([   920,    948,   1204,   1227,   1287,   1306,   1411,   2019,
#               3092,   3246,
#             ...
#             173421, 173641, 173713, 173759, 174403, 174905, 175117, 175315,
#             176183, 176271],
#            dtype='int64', name='movieId', length=259)

# %%
# https://seaborn.pydata.org/examples/kde_ridgeplot.html
# yoink!
plt.figure(figsize=(16,8));

# sns.set(style="white", rc={"axes.facecolor": (0, 0, 0, 0)})

# Create the data
# rs = np.random.RandomState(1979)
# x = rs.randn(500)
# g = np.tile(list("ABCDEFGHIJ"), 50)
df = pd.DataFrame(dict(runtime=INT_df["TMB_runtime"], g=release_decade)).dropna()
df.drop(df[df["g"].apply(lambda x: x in ["1890","1900"])].index, inplace=True)
df.drop(df[df["runtime"]>200].index, inplace=True)

# m = df.g.map(ord)
# df["x"] += m

# Initialize the FacetGrid object
pal = sns.cubehelix_palette(10, rot=-.25, light=.7)
g = sns.FacetGrid(df, row="g", hue="g", aspect=15, height=.75, palette=pal,
                  row_order = ['1910', '1920', '1930', '1940', '1950', '1960', '1970',
       '1980', '1990', '2000', '2010'], sharey=False);

# Draw the densities in a few steps
g.map(sns.kdeplot, "runtime", clip_on=False, shade=True, alpha=1, lw=1.5, bw=1)
g.map(sns.kdeplot, "runtime", clip_on=False, color="w", lw=2, bw=1)
g.map(plt.axhline, y=0, lw=2, clip_on=False)


# Define and use a simple function to label the plot in axes coordinates
def label(x, color, label):
    ax = plt.gca()
    ax.text(0, .2, label, fontweight="bold", color=color,
            ha="left", va="center", transform=ax.transAxes);


g.map(label, "runtime");

# Set the subplots to overlap
g.fig.subplots_adjust(hspace=-.25);
plt.xlim((0,200))

# Remove axes details that don't play well with overlap
g.set_titles("");
g.set(yticks=[]);
g.despine(bottom=True, left=True);

# %%
# %%time
global BES_output_folder
drop_cols = []
Treatment = "xgboost_numerical_only_with_agg_crew_cast_data_with_fusion_data"

# drop_cols.extend(fused_cols)

drop_cols.extend(["budget_normalised","gross_normalised",
                  "TMB_num_other_movies_with_same_homepage"]) # inflation is cheating!
var_name = "release_year"


BES_output_folder= ".."+os.sep+"Output"+os.sep


df = INT_df_ord_only.drop(drop_cols,axis=1).copy()
drop_movies = df[df.isnull().all(axis=1)].index
df.drop(drop_movies,inplace=True)
# standardise data (subtract out the mean, divide through by standard deviation)
df = pd.DataFrame(           StandardScaler().fit_transform(df.values ),
                             columns = df.columns,
                             index   = df.index      )

mask = df[var_name].notnull()
df = df[mask]
colname = var_name
var_stub = var_name
var_list = [var_name]
var_stub_list = [var_stub]

(explainer, shap_values) = xgboost_run(subdir=colname,min_features = min(df.shape[1]-1,20),
           title = colname+"\n\nPredicts Low "+colname+" <---   ---> Predicts High "+colname, dependence_plots=True, output_folder=BES_output_folder)
# Out:
# Warning, filename truncated because it was over 50. Filenames may no longer be unique
# C:\ProgramData\Anaconda3\envs\Cook_Tortoise_Imdb_project\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [19:46:42] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:1.09378
# Will train until validation_0-rmse hasn't improved in 50.800000000000004 rounds.
# [1]	validation_0-rmse:1.0721
# [2]	validation_0-rmse:1.05004
# [3]	validation_0-rmse:1.02976
# [4]	validation_0-rmse:1.01212
# [5]	validation_0-rmse:0.99417
# [6]	validation_0-rmse:0.980729
# [7]	validation_0-rmse:0.966917
# [8]	validation_0-rmse:0.95184
# [9]	validation_0-rmse:0.937434
# [10]	validation_0-rmse:0.924167
# [11]	validation_0-rmse:0.911967
# [12]	validation_0-rmse:0.900737
# [13]	validation_0-rmse:0.891212
# [14]	validation_0-rmse:0.880821
# [15]	validation_0-rmse:0.871199
# [16]	validation_0-rmse:0.861848
# [17]	validation_0-rmse:0.854241
# [18]	validation_0-rmse:0.847441
# [19]	validation_0-rmse:0.839432
# [20]	validation_0-rmse:0.832549
# [21]	validation_0-rmse:0.825685
# [22]	validation_0-rmse:0.820167
# [23]	validation_0-rmse:0.814003
# [24]	validation_0-rmse:0.80749
# [25]	validation_0-rmse:0.801607
# [26]	validation_0-rmse:0.796134
# [27]	validation_0-rmse:0.791283
# [28]	validation_0-rmse:0.786878
# [29]	validation_0-rmse:0.78241
# [30]	validation_0-rmse:0.778535
# [31]	validation_0-rmse:0.774204
# [32]	validation_0-rmse:0.770733
# [33]	validation_0-rmse:0.767126
# [34]	validation_0-rmse:0.763556
# [35]	validation_0-rmse:0.760436
# [36]	validation_0-rmse:0.757736
# [37]	validation_0-rmse:0.754321
# [38]	validation_0-rmse:0.752078
# [39]	validation_0-rmse:0.749597
# [40]	validation_0-rmse:0.746606
# [41]	validation_0-rmse:0.744544
# [42]	validation_0-rmse:0.742659
# [43]	validation_0-rmse:0.740717
# [44]	validation_0-rmse:0.738992
# [45]	validation_0-rmse:0.736557
# [46]	validation_0-rmse:0.734327
# [47]	validation_0-rmse:0.732525
# [48]	validation_0-rmse:0.730976
# [49]	validation_0-rmse:0.728704
# [50]	validation_0-rmse:0.727487
# [51]	validation_0-rmse:0.725325
# [52]	validation_0-rmse:0.723947
# [53]	validation_0-rmse:0.722445
# [54]	validation_0-rmse:0.721027
# [55]	validation_0-rmse:0.719462
# [56]	validation_0-rmse:0.717768
# [57]	validation_0-rmse:0.71613
# [58]	validation_0-rmse:0.714812
# [59]	validation_0-rmse:0.713866
# [60]	validation_0-rmse:0.712638
# [61]	validation_0-rmse:0.711548
# [62]	validation_0-rmse:0.710366
# [63]	validation_0-rmse:0.70895
# [64]	validation_0-rmse:0.707495
# [65]	validation_0-rmse:0.706481
# [66]	validation_0-rmse:0.705619
# [67]	validation_0-rmse:0.70474
# [68]	validation_0-rmse:0.703799
# [69]	validation_0-rmse:0.703114
# [70]	validation_0-rmse:0.701885
# [71]	validation_0-rmse:0.700997
# [72]	validation_0-rmse:0.700138
# [73]	validation_0-rmse:0.69944
# [74]	validation_0-rmse:0.698594
# [75]	validation_0-rmse:0.697689
# [76]	validation_0-rmse:0.696725
# [77]	validation_0-rmse:0.695967
# [78]	validation_0-rmse:0.695466
# [79]	validation_0-rmse:0.694718
# [80]	validation_0-rmse:0.693926
# [81]	validation_0-rmse:0.693099
# [82]	validation_0-rmse:0.692638
# [83]	validation_0-rmse:0.692092
# [84]	validation_0-rmse:0.69134
# [85]	validation_0-rmse:0.690223
# [86]	validation_0-rmse:0.689574
# [87]	validation_0-rmse:0.688915
# [88]	validation_0-rmse:0.688289
# [89]	validation_0-rmse:0.687361
# [90]	validation_0-rmse:0.686816
# [91]	validation_0-rmse:0.68636
# [92]	validation_0-rmse:0.685928
# [93]	validation_0-rmse:0.685451
# [94]	validation_0-rmse:0.684968
# [95]	validation_0-rmse:0.684595
# [96]	validation_0-rmse:0.683945
# [97]	validation_0-rmse:0.683495
# [98]	validation_0-rmse:0.683027
# [99]	validation_0-rmse:0.682606
# [100]	validation_0-rmse:0.681909
# [101]	validation_0-rmse:0.681282
# [102]	validation_0-rmse:0.680662
# [103]	validation_0-rmse:0.680301
# [104]	validation_0-rmse:0.679275
# [105]	validation_0-rmse:0.678621
# [106]	validation_0-rmse:0.678141
# [107]	validation_0-rmse:0.677469
# [108]	validation_0-rmse:0.676978
# [109]	validation_0-rmse:0.676651
# [110]	validation_0-rmse:0.676373
# [111]	validation_0-rmse:0.675489
# [112]	validation_0-rmse:0.675189
# [113]	validation_0-rmse:0.674869
# [114]	validation_0-rmse:0.674546
# [115]	validation_0-rmse:0.674027
# [116]	validation_0-rmse:0.673791
# [117]	validation_0-rmse:0.673129
# [118]	validation_0-rmse:0.672844
# [119]	validation_0-rmse:0.672562
# [120]	validation_0-rmse:0.672281
# [121]	validation_0-rmse:0.672104
# [122]	validation_0-rmse:0.671858
# [123]	validation_0-rmse:0.671543
# [124]	validation_0-rmse:0.671053
# [125]	validation_0-rmse:0.670648
# [126]	validation_0-rmse:0.670459
# [127]	validation_0-rmse:0.670101
# [128]	validation_0-rmse:0.669387
# [129]	validation_0-rmse:0.669068
# [130]	validation_0-rmse:0.668733
# [131]	validation_0-rmse:0.668481
# [132]	validation_0-rmse:0.668079
# [133]	validation_0-rmse:0.667676
# [134]	validation_0-rmse:0.66748
# [135]	validation_0-rmse:0.667194
# [136]	validation_0-rmse:0.666817
# [137]	validation_0-rmse:0.666566
# [138]	validation_0-rmse:0.666208
# [139]	validation_0-rmse:0.665762
# [140]	validation_0-rmse:0.665567
# [141]	validation_0-rmse:0.665318
# [142]	validation_0-rmse:0.665144
# [143]	validation_0-rmse:0.664695
# [144]	validation_0-rmse:0.664425
# [145]	validation_0-rmse:0.664246
# [146]	validation_0-rmse:0.664032
# [147]	validation_0-rmse:0.663542
# [148]	validation_0-rmse:0.663365
# [149]	validation_0-rmse:0.663038
# [150]	validation_0-rmse:0.662757
# [151]	validation_0-rmse:0.662598
# [152]	validation_0-rmse:0.662438
# [153]	validation_0-rmse:0.661927
# [154]	validation_0-rmse:0.66161
# [155]	validation_0-rmse:0.661404
# [156]	validation_0-rmse:0.661168
# [157]	validation_0-rmse:0.660829
# [158]	validation_0-rmse:0.660636
# [159]	validation_0-rmse:0.660478
# [160]	validation_0-rmse:0.660246
# [161]	validation_0-rmse:0.660128
# [162]	validation_0-rmse:0.659729
# [163]	validation_0-rmse:0.659325
# [164]	validation_0-rmse:0.659177
# [165]	validation_0-rmse:0.658939
# [166]	validation_0-rmse:0.658647
# [167]	validation_0-rmse:0.658373
# [168]	validation_0-rmse:0.658236
# [169]	validation_0-rmse:0.6581
# [170]	validation_0-rmse:0.657959
# [171]	validation_0-rmse:0.65776
# [172]	validation_0-rmse:0.657653
# [173]	validation_0-rmse:0.657532
# [174]	validation_0-rmse:0.657391
# [175]	validation_0-rmse:0.657123
# [176]	validation_0-rmse:0.656762
# [177]	validation_0-rmse:0.656646
# [178]	validation_0-rmse:0.656484
# [179]	validation_0-rmse:0.656274
# [180]	validation_0-rmse:0.656136
# [181]	validation_0-rmse:0.656039
# [182]	validation_0-rmse:0.655761
# [183]	validation_0-rmse:0.655567
# [184]	validation_0-rmse:0.655457
# [185]	validation_0-rmse:0.655316
# [186]	validation_0-rmse:0.655205
# [187]	validation_0-rmse:0.654892
# [188]	validation_0-rmse:0.654788
# [189]	validation_0-rmse:0.654628
# [190]	validation_0-rmse:0.654148
# [191]	validation_0-rmse:0.65389
# [192]	validation_0-rmse:0.65366
# [193]	validation_0-rmse:0.653456
# [194]	validation_0-rmse:0.653361
# [195]	validation_0-rmse:0.65324
# [196]	validation_0-rmse:0.652633
# [197]	validation_0-rmse:0.652503
# [198]	validation_0-rmse:0.652268
# [199]	validation_0-rmse:0.652134
# [200]	validation_0-rmse:0.652032
# [201]	validation_0-rmse:0.651837
# [202]	validation_0-rmse:0.651682
# [203]	validation_0-rmse:0.651527
# [204]	validation_0-rmse:0.651405
# [205]	validation_0-rmse:0.651314
# [206]	validation_0-rmse:0.650964
# [207]	validation_0-rmse:0.650858
# [208]	validation_0-rmse:0.650426
# [209]	validation_0-rmse:0.650012
# [210]	validation_0-rmse:0.649892
# [211]	validation_0-rmse:0.649751
# [212]	validation_0-rmse:0.649604
# [213]	validation_0-rmse:0.649457
# [214]	validation_0-rmse:0.649268
# [215]	validation_0-rmse:0.649139
# [216]	validation_0-rmse:0.648925
# [217]	validation_0-rmse:0.64882
# [218]	validation_0-rmse:0.648593
# [219]	validation_0-rmse:0.648489
# [220]	validation_0-rmse:0.64836
# [221]	validation_0-rmse:0.648268
# [222]	validation_0-rmse:0.648167
# [223]	validation_0-rmse:0.647975
# [224]	validation_0-rmse:0.647632
# [225]	validation_0-rmse:0.64754
# [226]	validation_0-rmse:0.647272
# [227]	validation_0-rmse:0.647155
# [228]	validation_0-rmse:0.64704
# [229]	validation_0-rmse:0.646878
# [230]	validation_0-rmse:0.646651
# [231]	validation_0-rmse:0.64644
# [232]	validation_0-rmse:0.646331
# [233]	validation_0-rmse:0.646239
# [234]	validation_0-rmse:0.646159
# [235]	validation_0-rmse:0.646063
# [236]	validation_0-rmse:0.645953
# [237]	validation_0-rmse:0.645791
# [238]	validation_0-rmse:0.645661
# [239]	validation_0-rmse:0.645571
# [240]	validation_0-rmse:0.645514
# [241]	validation_0-rmse:0.645424
# [242]	validation_0-rmse:0.645254
# [243]	validation_0-rmse:0.645069
# [244]	validation_0-rmse:0.64497
# [245]	validation_0-rmse:0.644877
# [246]	validation_0-rmse:0.644558
# [247]	validation_0-rmse:0.644461
# [248]	validation_0-rmse:0.644368
# [249]	validation_0-rmse:0.644058
# [250]	validation_0-rmse:0.643974
# [251]	validation_0-rmse:0.643829
# [252]	validation_0-rmse:0.643736
# [253]	validation_0-rmse:0.643591
# [254]	validation_0-rmse:0.643459
# [255]	validation_0-rmse:0.643351
# [256]	validation_0-rmse:0.643255
# [257]	validation_0-rmse:0.643198
# [258]	validation_0-rmse:0.64309
# [259]	validation_0-rmse:0.642989
# [260]	validation_0-rmse:0.6426
# [261]	validation_0-rmse:0.64254
# [262]	validation_0-rmse:0.642412
# [263]	validation_0-rmse:0.642275
# [264]	validation_0-rmse:0.64221
# [265]	validation_0-rmse:0.642126
# [266]	validation_0-rmse:0.641981
# [267]	validation_0-rmse:0.641881
# [268]	validation_0-rmse:0.641781
# [269]	validation_0-rmse:0.641739
# [270]	validation_0-rmse:0.641685
# [271]	validation_0-rmse:0.641565
# [272]	validation_0-rmse:0.641105
# [273]	validation_0-rmse:0.641044
# [274]	validation_0-rmse:0.640993
# [275]	validation_0-rmse:0.640907
# [276]	validation_0-rmse:0.640586
# [277]	validation_0-rmse:0.640487
# [278]	validation_0-rmse:0.640364
# [279]	validation_0-rmse:0.640338
# [280]	validation_0-rmse:0.640206
# [281]	validation_0-rmse:0.640131
# [282]	validation_0-rmse:0.64003
# [283]	validation_0-rmse:0.639913
# [284]	validation_0-rmse:0.639856
# [285]	validation_0-rmse:0.639669
# [286]	validation_0-rmse:0.639599
# [287]	validation_0-rmse:0.639396
# [288]	validation_0-rmse:0.639347
# [289]	validation_0-rmse:0.639101
# [290]	validation_0-rmse:0.639017
# [291]	validation_0-rmse:0.63893
# [292]	validation_0-rmse:0.638848
# [293]	validation_0-rmse:0.638768
# [294]	validation_0-rmse:0.638644
# [295]	validation_0-rmse:0.638588
# [296]	validation_0-rmse:0.6385
# [297]	validation_0-rmse:0.638383
# [298]	validation_0-rmse:0.638244
# [299]	validation_0-rmse:0.638161
# [300]	validation_0-rmse:0.638096
# [301]	validation_0-rmse:0.638036
# [302]	validation_0-rmse:0.637932
# [303]	validation_0-rmse:0.637829
# [304]	validation_0-rmse:0.637764
# [305]	validation_0-rmse:0.637515
# [306]	validation_0-rmse:0.637326
# [307]	validation_0-rmse:0.637191
# [308]	validation_0-rmse:0.637143
# [309]	validation_0-rmse:0.637074
# [310]	validation_0-rmse:0.63697
# [311]	validation_0-rmse:0.636928
# [312]	validation_0-rmse:0.636795
# [313]	validation_0-rmse:0.636732
# [314]	validation_0-rmse:0.636685
# [315]	validation_0-rmse:0.636555
# [316]	validation_0-rmse:0.636378
# [317]	validation_0-rmse:0.636301
# [318]	validation_0-rmse:0.636254
# [319]	validation_0-rmse:0.636194
# [320]	validation_0-rmse:0.636125
# [321]	validation_0-rmse:0.636071
# [322]	validation_0-rmse:0.636007
# [323]	validation_0-rmse:0.635934
# [324]	validation_0-rmse:0.635702
# [325]	validation_0-rmse:0.635652
# [326]	validation_0-rmse:0.635483
# [327]	validation_0-rmse:0.635391
# [328]	validation_0-rmse:0.635301
# [329]	validation_0-rmse:0.635213
# [330]	validation_0-rmse:0.635149
# [331]	validation_0-rmse:0.634997
# [332]	validation_0-rmse:0.634906
# [333]	validation_0-rmse:0.634844
# [334]	validation_0-rmse:0.634707
# [335]	validation_0-rmse:0.634605
# [336]	validation_0-rmse:0.634399
# [337]	validation_0-rmse:0.634346
# [338]	validation_0-rmse:0.634261
# [339]	validation_0-rmse:0.634192
# [340]	validation_0-rmse:0.634123
# [341]	validation_0-rmse:0.634019
# [342]	validation_0-rmse:0.633925
# [343]	validation_0-rmse:0.633857
# [344]	validation_0-rmse:0.633786
# [345]	validation_0-rmse:0.633754
# [346]	validation_0-rmse:0.6337
# [347]	validation_0-rmse:0.633619
# [348]	validation_0-rmse:0.633409
# [349]	validation_0-rmse:0.633338
# [350]	validation_0-rmse:0.633262
# [351]	validation_0-rmse:0.633198
# [352]	validation_0-rmse:0.633153
# [353]	validation_0-rmse:0.633135
# [354]	validation_0-rmse:0.633079
# [355]	validation_0-rmse:0.632987
# [356]	validation_0-rmse:0.632937
# [357]	validation_0-rmse:0.632885
# [358]	validation_0-rmse:0.63281
# [359]	validation_0-rmse:0.632744
# [360]	validation_0-rmse:0.632451
# [361]	validation_0-rmse:0.632357
# [362]	validation_0-rmse:0.632306
# [363]	validation_0-rmse:0.632266
# [364]	validation_0-rmse:0.632196
# [365]	validation_0-rmse:0.632134
# [366]	validation_0-rmse:0.632082
# [367]	validation_0-rmse:0.632049
# [368]	validation_0-rmse:0.631848
# [369]	validation_0-rmse:0.631803
# [370]	validation_0-rmse:0.631638
# [371]	validation_0-rmse:0.631571
# [372]	validation_0-rmse:0.631548
# [373]	validation_0-rmse:0.631466
# [374]	validation_0-rmse:0.631297
# [375]	validation_0-rmse:0.631245
# [376]	validation_0-rmse:0.631209
# [377]	validation_0-rmse:0.631164
# [378]	validation_0-rmse:0.631129
# [379]	validation_0-rmse:0.631092
# [380]	validation_0-rmse:0.631025
# [381]	validation_0-rmse:0.630962
# [382]	validation_0-rmse:0.6309
# [383]	validation_0-rmse:0.630861
# [384]	validation_0-rmse:0.630629
# [385]	validation_0-rmse:0.630565
# [386]	validation_0-rmse:0.630491
# [387]	validation_0-rmse:0.630417
# [388]	validation_0-rmse:0.630361
# [389]	validation_0-rmse:0.63021
# [390]	validation_0-rmse:0.630056
# [391]	validation_0-rmse:0.629962
# [392]	validation_0-rmse:0.629934
# [393]	validation_0-rmse:0.629846
# [394]	validation_0-rmse:0.629817
# [395]	validation_0-rmse:0.629795
# [396]	validation_0-rmse:0.629741
# [397]	validation_0-rmse:0.629674
# [398]	validation_0-rmse:0.629592
# [399]	validation_0-rmse:0.629466
# [400]	validation_0-rmse:0.629405
# [401]	validation_0-rmse:0.629369
# [402]	validation_0-rmse:0.629321
# [403]	validation_0-rmse:0.629276
# [404]	validation_0-rmse:0.62924
# [405]	validation_0-rmse:0.629208
# [406]	validation_0-rmse:0.629168
# [407]	validation_0-rmse:0.629136
# [408]	validation_0-rmse:0.629099
# [409]	validation_0-rmse:0.62908
# [410]	validation_0-rmse:0.629037
# [411]	validation_0-rmse:0.628913
# [412]	validation_0-rmse:0.628713
# [413]	validation_0-rmse:0.628615
# [414]	validation_0-rmse:0.628558
# [415]	validation_0-rmse:0.628498
# [416]	validation_0-rmse:0.628424
# [417]	validation_0-rmse:0.628358
# [418]	validation_0-rmse:0.628369
# [419]	validation_0-rmse:0.628291
# [420]	validation_0-rmse:0.62828
# [421]	validation_0-rmse:0.628225
# [422]	validation_0-rmse:0.628158
# [423]	validation_0-rmse:0.628089
# [424]	validation_0-rmse:0.628044
# [425]	validation_0-rmse:0.628013
# [426]	validation_0-rmse:0.627969
# [427]	validation_0-rmse:0.627911
# [428]	validation_0-rmse:0.627858
# [429]	validation_0-rmse:0.627782
# [430]	validation_0-rmse:0.627746
# [431]	validation_0-rmse:0.627625
# [432]	validation_0-rmse:0.627588
# [433]	validation_0-rmse:0.62749
# [434]	validation_0-rmse:0.627427
# [435]	validation_0-rmse:0.627377
# [436]	validation_0-rmse:0.627328
# [437]	validation_0-rmse:0.627328
# [438]	validation_0-rmse:0.627275
# [439]	validation_0-rmse:0.627226
# [440]	validation_0-rmse:0.627196
# [441]	validation_0-rmse:0.627155
# [442]	validation_0-rmse:0.627089
# [443]	validation_0-rmse:0.627019
# [444]	validation_0-rmse:0.626973
# [445]	validation_0-rmse:0.626795
# [446]	validation_0-rmse:0.62677
# [447]	validation_0-rmse:0.626711
# [448]	validation_0-rmse:0.626683
# [449]	validation_0-rmse:0.626629
# [450]	validation_0-rmse:0.62659
# [451]	validation_0-rmse:0.626561
# [452]	validation_0-rmse:0.626471
# [453]	validation_0-rmse:0.626378
# [454]	validation_0-rmse:0.626298
# [455]	validation_0-rmse:0.626263
# [456]	validation_0-rmse:0.626244
# [457]	validation_0-rmse:0.626047
# [458]	validation_0-rmse:0.625942
# [459]	validation_0-rmse:0.625755
# [460]	validation_0-rmse:0.625719
# [461]	validation_0-rmse:0.625673
# [462]	validation_0-rmse:0.625579
# [463]	validation_0-rmse:0.625484
# [464]	validation_0-rmse:0.625345
# [465]	validation_0-rmse:0.625234
# [466]	validation_0-rmse:0.6252
# [467]	validation_0-rmse:0.62509
# [468]	validation_0-rmse:0.625011
# [469]	validation_0-rmse:0.624957
# [470]	validation_0-rmse:0.624944
# [471]	validation_0-rmse:0.624832
# [472]	validation_0-rmse:0.624813
# [473]	validation_0-rmse:0.624788
# [474]	validation_0-rmse:0.624745
# [475]	validation_0-rmse:0.624711
# [476]	validation_0-rmse:0.624654
# [477]	validation_0-rmse:0.624618
# [478]	validation_0-rmse:0.6246
# [479]	validation_0-rmse:0.624507
# [480]	validation_0-rmse:0.624472
# [481]	validation_0-rmse:0.624342
# [482]	validation_0-rmse:0.624245
# [483]	validation_0-rmse:0.62414
# [484]	validation_0-rmse:0.624047
# [485]	validation_0-rmse:0.62395
# [486]	validation_0-rmse:0.623864
# [487]	validation_0-rmse:0.62371
# [488]	validation_0-rmse:0.623673
# [489]	validation_0-rmse:0.623603
# [490]	validation_0-rmse:0.623555
# [491]	validation_0-rmse:0.623535
# [492]	validation_0-rmse:0.623483
# [493]	validation_0-rmse:0.623367
# [494]	validation_0-rmse:0.62324
# [495]	validation_0-rmse:0.623208
# [496]	validation_0-rmse:0.623115
# [497]	validation_0-rmse:0.623074
# [498]	validation_0-rmse:0.623075
# [499]	validation_0-rmse:0.623063
# [500]	validation_0-rmse:0.623042
# [501]	validation_0-rmse:0.622992
# [502]	validation_0-rmse:0.622924
# [503]	validation_0-rmse:0.622862
# [504]	validation_0-rmse:0.622835
# [505]	validation_0-rmse:0.622804
# [506]	validation_0-rmse:0.622725
# [507]	validation_0-rmse:0.622676
# MSE: 0.39, MAE: 0.45, EV: 0.61, R2: 0.61
# C:\ProgramData\Anaconda3\envs\Cook_Tortoise_Imdb_project\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [20:00:32] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# C:\ProgramData\Anaconda3\envs\Cook_Tortoise_Imdb_project\lib\site-packages\shap\plots\summary.py:206: RuntimeWarning: invalid value encountered in greater
#   cvals[cvals_imp > vmax] = vmax
# C:\ProgramData\Anaconda3\envs\Cook_Tortoise_Imdb_project\lib\site-packages\shap\plots\summary.py:207: RuntimeWarning: invalid value encountered in less
#   cvals[cvals_imp < vmin] = vmin
# C:\ProgramData\Anaconda3\envs\Cook_Tortoise_Imdb_project\lib\site-packages\matplotlib\colors.py:512: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1
# Warning, filename truncated because it was over 30. Filenames may no longer be unique
# Warning, filename truncated because it was over 30. Filenames may no longer be unique
# Warning, filename truncated because it was over 30. Filenames may no longer be unique
# Warning, filename truncated because it was over 30. Filenames may no longer be unique
# Wall time: 51min 17s
